# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = yf.download('^IRX', start='2017-01-01', end='2020-12-31', interval='1mo')
print(data)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price       Close   High    Low   Open Volume
# Ticker       ^IRX   ^IRX   ^IRX   ^IRX   ^IRX
# Date
# 2017-01-01  0.500  0.535  0.473  0.488      0
# 2017-02-01  0.523  0.538  0.480  0.505      0
# 2017-03-01  0.738  0.775  0.608  0.625      0
# 2017-04-01  0.780  0.810  0.738  0.740      0
# 2017-05-01  0.950  0.955  0.778  0.780      0
# 2017-06-01  0.993  1.010  0.928  0.953      0
# 2017-07-01  1.053  1.173  0.998  1.000      0
# 2017-08-01  0.978  1.070  0.965  1.058      0
# 2017-09-01  1.028  1.053  0.970  0.980      0
# 2017-10-01  1.123  1.123  1.013  1.033      0
# 2017-11-01  1.238  1.290  1.123  1.123      0
# 2017-12-01  1.355  1.435  1.230  1.238      0
# 2018-01-01  1.430  1.443  1.368  1.388      0
# 2018-02-01  1.618  1.640  1.420  1.425      0
# 2018-03-01  1.670  1.760  1.588  1.610      0
# 2018-04-01  1.763  1.835  1.660  1.683      0
# 2018-05-01  1.870  1.893  1.780  1.823      0
# ...

# %%
plt.figure(figsize=(16,4))
plt.plot(data.index, data['Close']);
